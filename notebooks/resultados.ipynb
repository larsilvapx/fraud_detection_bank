# %%
from src.pipeline import executar_pipeline

resultado_log, resultado_rf = executar_pipeline()

print(resultado_log["metricas"])

# %%
from src.models import treinar_logistic_regression

resultado = treinar_logistic_regression()

resultado["metricas"]

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from src.pipeline import executar_pipeline

resultado_log, resultado_rf = executar_pipeline()

# %%
from src.preprocessing import preparar_dados

X_train, X_test, y_train, y_test = preparar_dados()

# %%
from src.visualization import (
    plot_confusion_matrix,
    plot_roc_curve,
    plot_feature_importance
)

plot_confusion_matrix(
    resultado_rf["modelo"],
    X_test,
    y_test
)

plot_roc_curve(
    resultado_rf["modelo"],
    X_test,
    y_test
)

plot_feature_importance(
    resultado_rf["modelo"],
    X_train
)
