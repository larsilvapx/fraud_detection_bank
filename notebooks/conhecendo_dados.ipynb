# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Analise_Dados\fraud_detection_bank\notebooks
# ['conhecendo_dados.ipynb']

# %%
import pandas as pd

df = pd.read_csv("C:/Analise_Dados/fraud_detection_bank/data/raw/creditcard.csv")
df.head() ## Carregar o dataset

#df.shape ## Tamanho do dataframe

#df.info ## tipos de colunas

#df.describe() ## entender a distribuição dos dados e identificar possíveis valores extremos.

df.isnull().sum() ## coletar valores nulos

#df['Class'].value_counts()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
percentual_fraudes = (
    df['Class'].value_counts(normalize=True) * 100
)
print(f'Transações normais: {percentual_fraudes[0]:.2f}%')
print(f'Transações fraudulentas: {percentual_fraudes[1]:.2f}%')
# Out:
# Transações normais: 99.83%
# Transações fraudulentas: 0.17%
