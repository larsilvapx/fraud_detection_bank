# %%
import sys
from pathlib import Path

# Caminho da raiz do projeto
ROOT = Path.cwd().parent

# Adiciona a raiz ao PATH
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("Raiz do projeto:", ROOT)

import sys

for caminho in sys.path:
    print(caminho)
# Out:
# Raiz do projeto: c:\Analise_Dados\fraud_detection_bank
# c:\Analise_Dados\fraud_detection_bank
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\python311.zip
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\DLLs
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0
# c:\Analise_Dados\fraud_detection_bank\.venv
#
# c:\Analise_Dados\fraud_detection_bank\.venv\Lib\site-packages

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       2
#       3 comparacao = pd.DataFrame([
#       4     {
#       5         "Modelo": "Logistic Regression",
# ----> 6         **resultado_log["metricas"]
#       7     },
#       8     {
#       9         "Modelo": "Random Forest",
#
# NameError: name 'resultado_log' is not defined
